# %%
import pandas as pd


# Read Excel file from local Drive 
df = pd.read_excel('/content/drive/MyDrive/Sailpoint_midlevels.xlsx')
df['LocCode/DeptCode/JobCode']

# %% [markdown]
# Splitting a multiple Value Column

# %%
df_temp =df['LocCode/DeptCode/JobCode'].str.split("/", expand=True)

cols = []

for col in df_temp:
    df_temptemp = df_temp[col].str.split("/", expand=True)
    #print(df_temptemp)
    df_temp[col] = df_temptemp[0]
    
    cols.append(df_temptemp.iloc[0, 0])
df_temp.columns = cols

print(df_temp)

# %% [markdown]
# ##### Zipping a file

# %%
import os 
from zipfile import ZipFile 


zipObj= ZipFile('sample.zip', 'w')

for file in os.listdir(): 
    if file.endswith('.txt'):
        zipObj.write(file)

# %% [markdown]
# Mounting G-Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Data Analysis CAM

# %%
import pandas as pd


# Read Excel file from local Drive 
df = pd.read_excel('/content/drive/MyDrive/DataSets/CAM_TICKET_LIFE_CYCLE_2021.xlsx')

# %%
from datetime import time, datetime

df_temp =df['ADMIN_APPROVAL_TIME']
#df strftime("%H:%M:%S")
len(df_temp)
df_temptemp=list()
for val in range(len(df_temp)):
  if not pd.isna(df_temp[val]):   # handling nan values 
    df_temptemp.append(datetime.strptime(str(df_temp[val]).split(" ")[1].replace(".000000","").strip(),"%H:%M:%S" ))


len(df_temptemp)
df_temptemp

# %%
from datetime import time

# %%
df_row= df.sort_values(by=['TICKET_CREATED']).groupby(['BH_AC_REQUEST_ID']).count()

# %%
df_row
# Out:
#                    BH_AC_HOME_COMPANY  CREATED_BY  REQUESTOR_ID  \
# BH_AC_REQUEST_ID
# REQ00000000117439                   2           2             2
# REQ00000000117765                  69          69            69
# REQ00000000117766                  32          32            32
# REQ00000000117767                  46          46            46
# REQ00000000117768                  34          34            34
# ...                               ...         ...           ...
# REQ00000000182175                   1           1             1
# REQ00000000182176                   3           3             3
# REQ00000000182177                   3           3             3
# REQ00000000182178                   6           6             6
# REQ00000000182179                   1           1             1
#
#                    REQUESTOR_NAME  REQUEST_TYPE  BH_AC_REQUEST_STAT  \
# BH_AC_REQUEST_ID
# REQ00000000117439               2             2                   2
# ...

# %%
df_row2= df.sort_values(by=['TICKET_CREATED']).groupby(['BH_AC_REQUEST_ID']).count()

# %%
# Boolean Masking 

df_row3= df.loc[df.APPLICATION_ID.isin(['APP000000000018','APP000000000001'])]
df_row4=df_row3.loc[:,['BH_AC_REQUEST_ID','TOTAL_TIME']]
df_row5= df_row4.groupby("BH_AC_REQUEST_ID").sum()

# %%
df_row5
# Out:
#                                                           TOTAL_TIME
# BH_AC_REQUEST_ID
# REQ00000000117439  +000000000 00:41:33.000000+000000000 00:27:48....
# REQ00000000117765                         +000000000 02:40:32.000000
# REQ00000000117766  +000000000 01:06:47.000000+000000000 01:05:56....
# REQ00000000117767  +000000000 02:30:51.000000+000000000 02:29:47....
# REQ00000000117768  +000000000 03:07:28.000000+000000000 03:06:32....
# ...                                                              ...
# REQ00000000182171                         +000000000 05:59:43.000000
# REQ00000000182173  +000000000 00:27:52.000000+000000000 00:24:10....
# REQ00000000182174  +000000000 00:56:37.000000+000000000 00:54:05....
# REQ00000000182176                         +000000000 00:20:56.000000
# REQ00000000182177                         +000000000 01:19:43.000000
#
# [42546 rows x 1 columns]

# %%
# Unique values of a column 

df.APPLICATION_DESCRIPTION.unique()

# %%
import pandas as pd

df = pd.read_csv("/content/drive/MyDrive/DataSets/PS emp users_112822.csv", sep = '|',encoding = 'ISO-8859-1')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df['DOB']
# Out:
# 0         524.0
# 1         913.0
# 2        1209.0
# 3         915.0
# 4        1007.0
#           ...
# 36243     506.0
# 36244    1211.0
# 36245     304.0
# 36246     712.0
# 36247     624.0
# Name: DOB, Length: 36248, dtype: float64

# %%
df.to_csv('raw_dataII.csv', index=False)

# %%
from google.colab import files
files.download('raw_dataII.csv')
